# %%
! pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 4.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from sentence_transformers import SentenceTransformer
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
print(f"model details: {model}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ...

# %%
#sentences1

sentences1 = ['Pandas eat bamboo leaves primarily.',
              'Pandas have distinctive black patches.',
              'Pandas are animals.',
              'Conservationists work to save pandas.'
             ]

print(f"About Pandas - sentences1:\n {sentences1}\n")

#sentences2

sentences2 = ['Tigers are large, carnivorous felines.',
              'Stripes adorn a tiger fur coat.',
              'Tigers are wild animals.',
              'Tigers habitats include dense forests.'
             ]

print(f"About Tiger - sentences2:\n {sentences2}")
# Out:
# About Pandas - sentences1:
#  ['Pandas eat bamboo leaves primarily.', 'Pandas have distinctive black patches.', 'Pandas are animals.', 'Conservationists work to save pandas.']
#
# About Tiger - sentences2:
#  ['Tigers are large, carnivorous felines.', 'Stripes adorn a tiger fur coat.', 'Tigers are wild animals.', 'Tigers habitats include dense forests.']

# %%
embedding1 = model.encode(sentences1, convert_to_tensor=True)
print(f'embedding1(numerical vector representation for Panda-sentences-1): \n\n {embedding1}')
# Out:
# embedding1(numerical vector representation for Panda-sentences-1):
#
#  tensor([[-0.0185, -0.0165,  0.0007,  ...,  0.0530,  0.0574,  0.0581],
#         [-0.0318, -0.0361, -0.0344,  ..., -0.0337,  0.0014,  0.0583],
#         [ 0.0192, -0.0501,  0.0255,  ...,  0.0416,  0.0592,  0.0581],
#         [-0.0111,  0.0247,  0.0235,  ...,  0.0043,  0.0382,  0.0663]])

# %%
print(embedding1.shape)
# Out:
# torch.Size([4, 384])

# %%
sample_stament = "animesh"

# %%
embedding_sample = model.encode(sample_stament, convert_to_tensor=True)
# print(f'embedding_sample(numerical vector representation for sample_stament): \n\n {embedding_sample}')
print(f'embedding_sample.shape: {embedding_sample.shape}')
# Out:
# embedding_sample(numerical vector representation for sample_stament):
#
#  tensor([-4.7899e-02, -1.6061e-03,  3.7807e-02, -2.8756e-03, -2.9279e-02,
#         -4.7769e-02,  1.2784e-01,  4.1964e-02,  1.6737e-02, -1.9346e-02,
#          5.6460e-02, -1.3163e-01, -1.0986e-02, -5.0547e-03, -4.4222e-02,
#         -8.9029e-03,  3.2742e-02,  7.9064e-03, -3.7809e-02, -1.5283e-02,
#         -5.0771e-02,  3.0675e-02, -3.0507e-02, -1.3498e-02,  2.2954e-02,
#         -3.0080e-02,  2.1749e-02, -7.2023e-03, -4.1338e-02, -4.8745e-02,
#         -1.3222e-03,  1.1924e-02,  8.2018e-02,  1.2045e-02, -4.0776e-02,
#          7.4285e-02,  9.8964e-02,  1.9155e-02, -4.4707e-02,  5.7644e-02,
#         -7.5498e-02,  8.8493e-03, -1.9313e-02, -9.5584e-02,  2.6280e-02,
#          4.3011e-02,  4.7287e-02, -7.5489e-02,  8.8340e-02,  9.1454e-03,
#         -6.1718e-02, -4.4440e-02, -2.6007e-02,  9.9936e-02,  4.3094e-02,
#         -6.7812e-02,  3.7811e-02,  6.9597e-03, -8.3180e-03, -1.5142e-02,
# ...

# %%
print(f"the dimensions of embedding modles is alomst this model is{model}")
# dimension is 384
# Out:
# the dimensions of embedding modles is alomst this model isSentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %% [markdown]
# Lets see diffent dirrent models on the leader bord and see the comparison of the mode we will see the bes ebdding models that can do best in our use case![image.png](data:image/png;base64,...)
#
#  https://huggingface.co/spaces/mteb/leaderboard

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("Salesforce/SFR-Embedding-2_R")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/205 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/54.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/22.2k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.28G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.5/327.5 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import userdata

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %%
api_key=userdata.get('OPENAI_API_KEY')

# %%
model_name ="text-embedding-3-small"

# %%
from openai import OpenAI
import time
openai_client = OpenAI( api_key=userdata.get('OPENAI_API_KEY'))
# Replace newline characters with spaces to avoid issues with the OpenAI API
text_to_embed = "Can you tell me how can I utilize it?"
start_time_to_embed = time.time()
# Generate the embedding using the OpenAI API
response = openai_client.embeddings.create(input=text_to_embed, model=model_name, dimensions=1536)
end_time_to_embed = time.time()
elapsed_time_to_embed = (end_time_to_embed - start_time_to_embed) * 1000
print(f"Elapsed time to embed text on google collab usinf {model_name} : {elapsed_time_to_embed:.4f} milliseconds")
# Out:
# Elapsed time to embed text on google collab usinf text-embedding-3-small : 221.9877 milliseconds

# %%
model_name ="text-embedding-3-large"

# %%
from openai import OpenAI
import time
openai_client = OpenAI( api_key=userdata.get('OPENAI_API_KEY'))
# Replace newline characters with spaces to avoid issues with the OpenAI API
text_to_embed = "Can you tell me how can I utilize it?"
start_time_to_embed = time.time()
# Generate the embedding using the OpenAI API
response = openai_client.embeddings.create(input=text_to_embed, model=model_name, dimensions=1536)
end_time_to_embed = time.time()
elapsed_time_to_embed = (end_time_to_embed - start_time_to_embed) * 1000
print(f"Elapsed time to embed text on google collab usinf {model_name} : {elapsed_time_to_embed:.4f} milliseconds")
# Out:
# Elapsed time to embed text on google collab usinf text-embedding-3-large : 247.7541 milliseconds

# %%
model_name ="text-embedding-ada-002"

# %% [markdown]
# This model does not support specifying dimensions. its fixed 1536

# %%
from openai import OpenAI
import time
openai_client = OpenAI( api_key=userdata.get('OPENAI_API_KEY'))
# Replace newline characters with spaces to avoid issues with the OpenAI API
text_to_embed = "Can you tell me how can I utilize it?"
start_time_to_embed = time.time()
# Generate the embedding using the OpenAI API
response = openai_client.embeddings.create(input=text_to_embed, model=model_name)
end_time_to_embed = time.time()
elapsed_time_to_embed = (end_time_to_embed - start_time_to_embed) * 1000
print(f"Elapsed time to embed text on google collab usinf {model_name} : {elapsed_time_to_embed:.4f} milliseconds")
# Out:
# Elapsed time to embed text on google collab usinf text-embedding-ada-002 : 257.5264 milliseconds

# %%
from openai import OpenAI
import time

def test_model_latency(model_name, api_key, text_to_embed):
    openai_client = OpenAI(api_key=api_key)

    # Replace newline characters with spaces to avoid issues with the OpenAI API
    text_to_embed = text_to_embed.replace('\n', ' ')

    start_time_to_embed = time.time()

    # Generate the embedding using the OpenAI API
    response = openai_client.embeddings.create(input=text_to_embed, model=model_name, dimensions=1536)

    end_time_to_embed = time.time()
    elapsed_time_to_embed = (end_time_to_embed - start_time_to_embed) * 1000

    print(f"Elapsed time to embed text using {model_name} : {elapsed_time_to_embed:.4f} milliseconds")

# %%
text_to_embed = "Can you tell me how can I utilize it?"

# %% [markdown]
# ##Voyagenai emdeddings
# https://docs.voyageai.com/docs/embeddings

# %%
# !pip install voyageai

# %%
import os
from google.colab import userdata
import voyageai
os.environ['VOYAGE_API_KEY'] =userdata.get('VOYAGE_API_KEY')
vo = voyageai.Client(api_key=os.environ.get("VOYAGE_API_KEY"))

# %%
# Prepare data
documents = ["Can you tell me how can I utilize it?"]

# %%
# Embed the documents
documents_embeddings = vo.embed(documents, model="voyage-2", input_type="document").embeddings

# %%
print(f"The dimenstions of the embedding VOYAGE is {len(documents_embeddings[0])}")
# Out:
# The dimenstions of the embedding VOYAGE is 1024

# %% [markdown]
# Time decorator function

# %%
import time

def time_it(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f'Function {func.__name__} took {elapsed_time:.6f} seconds to run')
        return result
    return wrapper

# %%
@time_it
def get_embeddings_voyage(documents, model_name="voyage-2"):
    """
    This function takes a list of documents and a model name, and returns the embeddings for each document.

    Parameters:
    documents (list): A list of documents to be embedded.
    model_name (str): The name of the model to be used for embedding. Default is "voyage-2".

    Returns:
    embeddings (list): A list of embeddings for the given documents.
    """
    embeddings = []
    for doc in documents:
        embedding = vo.embed(doc, model=model_name, input_type="document").embeddings
        embeddings.append(embedding)
    return embeddings

# %%
text_to_embed = "Can you tell me how can I utilize it?"
voyage_embeddding=get_embeddings_voyage(text_to_embed)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-17-42ab13d66e95> in <cell line: 2>()
#       1 text_to_embed = "Can you tell me how can I utilize it?"
# ----> 2 voyage_embeddding=get_embeddings_voyage(text_to_embed)
#
# <ipython-input-14-4d53db0ce4ef> in wrapper(*args, **kwargs)
#       4     def wrapper(*args, **kwargs):
#       5         start_time = time.time()
# ----> 6         result = func(*args, **kwargs)
#       7         end_time = time.time()
#       8         elapsed_time = end_time - start_time
#
# <ipython-input-15-fcc5268e2e4d> in get_embeddings_voyage(documents, model_name)
#      13     embeddings = []
#      14     for doc in documents:
# ---> 15         embedding = vo.embed(doc, model=model_name, input_type="document").embeddings
#      16         embeddings.append(embedding)
#      17     return embeddings
#
# ...

# %% [markdown]
# Converting the above model in to a fucntion so that it can be used easily

# %% [markdown]
# There are many diffrent diffrent embedding models present out there you need to select the model according to your use cas either you download the model and run do the embedding part and save the docs in the encodding . at time of makeing th knowledge  base its ok to run a local model on the gpu or cpu(for small models ) but the problem comes in the retirval part the model are huge so when running the rang in the actual code there is the need of the embedding model to created the user query and then perform the similalrity search but this over all task can consume lot of compute power to the embedding part on the user query will be done on the cpu and this will require huge computaion power and enenvtyully the cost of runnig that as the api will be almost equal so this is why most the provieder rovied the hhtps request to retive the relenct dcuments the embedding .
# but there are time when you want to do the reduce the lantecy of the overall system ,and in the https calls the latency would be depond on the interspeet speed as well as the location of the cloud machine it is palced , let me share you share one example of how much this lancty depends upon when i run a simple
#
#
#
#
# Local Embedding Models:
#
# Running models locally allows for control over latency and data privacy.
# Small models can run on a CPU, but larger ones require a GPU.
# Embedding queries locally can consume significant computational resources.
# Using APIs:
#
# APIs can offload the computation to external servers, potentially reducing local resource usage.
# Latency can depend on internet speed and server location.
# API usage costs may accumulate based on request volume.
# Latency Considerations:
#
# Local execution reduces dependency on network conditions.
# Cloud-based solutions may introduce delays, influenced by factors like geographical distance to data centers.
# Performance Optimization:
#
# Consider hybrid approaches, such as using local models for frequent queries and APIs for more complex tasks.
# Evaluate the cost versus performance trade-offs based on your specific use case.
